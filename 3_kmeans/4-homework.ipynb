# %%
path = ("circle.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(path)
data = np.array(data)

# %%
print(data)
print(data)
# Out:
# [[ -0.13434055   9.60981487   0.        ]
#  [-11.76738926   0.04803148   0.        ]
#  [ -0.81879282  10.49254654   0.        ]
#  ...
#  [ 21.27632507   0.84371986   1.        ]
#  [-14.07077715 -20.20577296   1.        ]
#  [ 22.93969908  -1.19479686   1.        ]]
# [-11.76738926   0.04803148   0.        ]

# %%
x1 = []
y1 = []
x2 = []
y2 = []
for item in data:
    if(item[2]==0):
        x1.append(item[0])
        y1.append(item[1])
    else:
        x2.append(item[0])
        y2.append(item[1])
print(len(x1))
print(len(y1))
print(len(x2))
print(len(y2))
# Out:
# 199
# 199
# 200
# 200

# %%
plt.scatter(x1, y1, marker='*', s=100)
plt.scatter(x2, y2, marker='<', s=100)
plt.savefig('data_cluster.pdf')
plt.show()
